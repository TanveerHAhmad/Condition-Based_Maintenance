# %%
import pandas as pd

# %%
Maersk = pd.read_csv(r'MAERSK_Annular_2017_02_26_to_2017_06_19.csv', sep='\t')

# %%
Maersk.tail()
# Out:
#         last_active_time\tactivePod\tlower_ann_open_current\tlower_ann_close_current\tlower_ann_regul_rdbak_pres_podtrans\tuser_entered_reference_pres_podtrans\tPressure_Correction_Factor\tlower_ann_regul_pilot_pres_podtrans\tupper_ann_regul_rdbak_pres_podtrans\tupper_ann_regul_pilot_pres_podtrans\tupper_ann_open_current\tupper_ann_close_current\tsurface_flow_meter_tot1\tsurface_flow_meter_tot2\tpod_1_flow_meter_total1\tpod_1_flow_meter_total2\tpod_2_flow_meter_total1\tpod_2_flow_meter_total2\tpod_3_flow_meter_total1\tpod_3_flow_meter_total2\tpod_4_flow_meter_total1\tpod_4_flow_meter_total2\tstack_hpht_temp_raw\tstack_hpht_temp_bias\tstack_hpht_temp_corrected\tstack_hpht_pres_raw\tstack_hpht_pres_bias\tstack_hpht_pres_corrected\tlmrp_hpht_pres_raw\tlmrp_hpht_pres_bias\tlmrp_hpht_pres_corrected\tlmrp_hpht_temp_raw\tlmrp_hpht_temp_bias\tlmrp_hpht_temp_corrected\tsolenoid_1_spare_firedstatus\tsolenoid_02_eh_spare_only_firedstatus\tautoshear_ctrl_res_firedstatus\tmani_regul_pres_inc_fire
# ...
