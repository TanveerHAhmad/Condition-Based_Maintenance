# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

#from subprocess import check_output
#from datetime import time
# %matplotlib inline

# %%
#df = pd.read_csv("LIONS_2017_04_24_to_2017_08_07.csv", usecols= ['last_active_time','UA RegPilotPes_adj', 'UA RegRdbakPes_adj', 'pod_pilot_pres_podtrans_adj', 'pod_supply_pres_podtrans_adj', 'upper_ann_open_current', 'upper_ann_close_current'])
df = pd.read_csv("LIONS_2017_04_24_to_2017_08_07.csv")

# %%
df.head()
# Out:
#       last_active_time  Active  UA RegPilotPes  UA RegRdbakPes  \
# 0  2017-04-24 08:40:28       2     1363.050049        0.000000
# 1  2017-04-24 08:40:36       2     2982.010010     3073.770020
# 2  2017-04-24 08:40:41       2     2969.149902     3073.770020
# 3  2017-04-24 08:40:46       2     2969.149902     3073.770020
# 4  2017-04-24 08:40:51       2     2943.439941     3060.110107
#
#    pod_pilot_pres_podtrans  pod_supply_pres_podtrans  upper_ann_open_current  \
# 0              3097.669922               3143.840088                     223
# 1              4604.109863               4467.209961                     223
# 2              4604.109863               4535.520020                     223
# 3              4604.109863               4617.490234                     223
# 4              4604.109863               4617.490234                     223
#
#    upper_ann_close_current  pod_2_adj  pod_1_adj  UA RegPilotPes_adj  \
# ...

# %%
# Choose label
y = df["UA RegPilotPes_adj"]

# %%
df_features = ["UA RegRdbakPes_adj", "pod_pilot_pres_podtrans_adj", "pod_supply_pres_podtrans_adj"]
X = df[df_features]

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y,random_state = 0)

# %%
type(val_X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
# Y prediction
#preds = forest_model.predict(val_X)

preds = forest_model.predict(df[df_features ])

# %%
type(preds)
# Out:
# numpy.ndarray

# %%
df["UA RegPilotPes_adj_predicted"] = preds

# %%
print(preds)
# Out:
# [ 1376.94700928  2904.88598633  2903.59997559 ...,  1411.70599607
#   1411.70599607  1445.46984863]

# %%
df_temp = df[[ "last_active_time", "UA RegPilotPes_adj", "UA RegPilotPes_adj_predicted"]]

# %%
df_temp['last_active_time'] = pd.to_datetime(df_temp['last_active_time'])
# Out:
# C:\Users\1535980\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_temp["UA RegPilotPes_adj"].plot()
#plt.plot(df[["last_active_time"]], df[["UA RegPilotPes_adj"]])
#plt.plot(df[["last_active_time"]], df[["UA RegPilotPes_adj_predicted"]])
#plt.show()

# %%
df_temp["UA RegPilotPes_adj_predicted"].plot()

# %%
a4_dims = (16, 8.27)

# %%
plt.plot(df_temp["UA RegPilotPes_adj"])
plt.plot(df_temp["UA RegPilotPes_adj_predicted"])
plt.show()

# %%
a4_dims = (16, 8.27)

# %%
fig, ax = plt.subplots(figsize=a4_dims)
ax = df_temp["UA RegPilotPes_adj"].plot()
df_temp["UA RegPilotPes_adj_predicted"].plot(ax=ax, figsize=a4_dims)
plt.legend(['Y_TEST','Y_PRED'])
#plt.legend(['train','test'])
#plt.plot(df_temp["UA RegPilotPes_adj"])
#plt.plot(df_temp["UA RegPilotPes_adj_predicted"])
#plt.show()
#fig, ax = plt.subplots(figsize=a4_dims)
#ax = train.plot()
#test.plot(ax=ax, figsize=a4_dims)
#plt.legend(['train','test'])

# %%
#Y_TEST = pd.DataFrame(y_test_inv_t, columns = ['event_count'],index= test[49:].index)
#Y_PRED = pd.DataFrame(y_pred_inv_t, columns = ['event_count'],index= test[49:].index)

# %%
plt.figure(figsize=(16,10))
plt.plot(df_temp["last_active_time"], df_temp["UA RegPilotPes_adj"], '-.', color="red")
plt.plot(df_temp["last_active_time"], df_temp["UA RegPilotPes_adj_predicted"], color="blue")
#plt.plot(x, y_3, '-', color="#aaaaaa")
plt.show()

# %%
a4_dims = (16, 8.27)

# %%
ax = Y_TEST[:].plot()
Y_PRED[:].plot(ax=ax, figsize=a4_dims)
plt.legend(['Y_TEST','Y_PRED'])

ax = df[][:].plot()
Y_PRED[:].plot(ax=ax, figsize=a4_dims)
plt.legend(['Y_TEST','Y_PRED'])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-1a99a89edab0> in <module>()
# ----> 1 df["UA RegPilotPes_adj_pred"]= preds
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# ...
